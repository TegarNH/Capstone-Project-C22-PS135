# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GitHub/
# Out:
# /content/drive/MyDrive/GitHub

# %%
# !git init capstone
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/GitHub/capstone/.git/

# %%
# %cd capstone
# Out:
# /content/drive/MyDrive/GitHub/capstone

# %%
# %ls -a
# Out:
# .git/

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git remote add https://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@github.com/TegarNH/Capstone-Project-C22-PS135.git
# Out:
# usage: git remote add [<options>] <name> <url>
#
#     -f, --fetch           fetch the remote branches
#     --tags                import all tags and associated objects when fetching
#                           or do not fetch any tag at all (--no-tags)
#     -t, --track <branch>  branch(es) to track
#     -m, --master <branch>
#                           master branch
#     --mirror[=<push|fetch>]
#                           set up remote as a mirror to push to or fetch from

# %%
# !git pull https://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@github.com/TegarNH/Capstone-Project-C22-PS135.git main
# Out:
# remote: Enumerating objects: 1145, done.
# remote: Counting objects: 100% (815/815), done.
# remote: Compressing objects: 100% (792/792), done.
# remote: Total 1145 (delta 40), reused 751 (delta 21), pack-reused 330
# Receiving objects: 100% (1145/1145), 33.71 MiB | 13.61 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# From https://github.com/TegarNH/Capstone-Project-C22-PS135
#  * branch            main       -> FETCH_HEAD
# Checking out files: 100% (1788/1788), done.

# %%
# !git add .
# Out:
# ^C
